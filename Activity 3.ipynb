# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
accident = pd.read_csv('Dataset//accident_data.csv')

# %%
accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
#  13  Vehicle_Type             660679 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.6+ MB

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])

# %%
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna(accident['Road_Surface_Conditions'].mode()[0])

# %%
accident['Road_Type'] = accident['Road_Type'].fillna(accident['Road_Type'].mode()[0])

# %%
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mean())

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mean())

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                       0
# Light_Conditions               0
# District Area                  0
# Longitude                      0
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions        0
# Road_Type                      0
# Urban_or_Rural_Area            0
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       646551 non-null  object
#  13  Vehicle_Type             660679 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.6+ MB

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accident.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                   object
# District Area                      object
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# dtype: object

# %%
categorical_columns = [
    'Accident_Severity', 'Light_Conditions', 'District Area', 
    'Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area', 
    'Weather_Conditions', 'Vehicle_Type'
]

for col in categorical_columns:
    accident[col] = accident[col].astype('category')

# Check the data types again
print(accident.dtypes)
# Out:
# Index                              object
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                 category
# District Area                    category
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# dtype: object

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious           NaT  51.517715
# 3       200701BS66128           Serious           NaT  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight           NaT  57.374005
# 660675  201091NM01881            Slight           NaT  57.232273
# 660676  201091NM01935            Slight           NaT  57.585044
# 660677  201091NM01964           Serious           NaT  57.214898
# 660678  201091NM02142           Serious           NaT  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2       Single carriageway               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4       Single carriageway               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %% [markdown]
# <h1>MAKE INSTANCES</h1>

# %% [markdown]
# <H1>UNIVARIATE</H1>

# %% [markdown]
# <h1>1 .WHAT IS THE TOTAL NUMBER OF ACCIDENTS IN EACH SEVERITY?</h1>

# %% [markdown]
# <H2>Insight 1. There is a total of 563,801 slight accidents</H2>
# <h2>Insight 2. There is a total of 88,217 Serious accidents</h2>
# <h2>Insight 3. There is a total of 8,661 Fatal accidents</h2>

# %%
(accident['Accident_Severity'].value_counts())
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# <H1>2.WHAT IS THE PERCENTAGE OF ACCIDENT SEVERITY IN 2019?</H1>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'])
accident['Year'] = accident['Accident Date'].dt.year
accident_2019 = accident[accident['Year'] == 2019]
severity_percentage_2019 = accident_2019['Accident_Severity'].value_counts(normalize=True) * 100
severity_percentage_2019 = np.round(severity_percentage_2019, 2)
(severity_percentage_2019)
# Out:
# Accident_Severity
# Slight     84.78
# Serious    13.67
# Fatal       1.55
# Name: proportion, dtype: float64

# %% [markdown]
# <H2>Insight 4. There is 84.78% percent of slight accidents in 2019 followed by 13.67% of serious accidents and 1.55% of fatal accidents</H2>

# %% [markdown]
# <H1>3. WHAT IS THE PERCENTAGE OF accident SEVERITY IN 2020?</H1>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'])
accident['Year'] = accident['Accident Date'].dt.year
accident_2020 = accident[accident['Year'] == 2020]
severity_percentage_2020 = accident_2020['Accident_Severity'].value_counts(normalize=True) * 100
severity_percentage_2020 = np.round(severity_percentage_2020, 2)
(severity_percentage_2020)
# Out:
# Accident_Severity
# Slight     85.34
# Serious    13.32
# Fatal       1.34
# Name: proportion, dtype: float64

# %% [markdown]
# <H2>Insight 5. There is 85.34% percent of slight accidents in 2020 followed by 13.32% of serious accidents and 1.34% of fatal accidents</H2>

# %% [markdown]
# <H1>4. WHAT IS THE PERCENTAGE OF ACCIDENT SEVERITY IN 2021?</H1>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'])
accident['Year'] = accident['Accident Date'].dt.year
accident_2021 = accident[accident['Year'] == 2021]
severity_percentage_2021 = accident_2021['Accident_Severity'].value_counts(normalize=True) * 100
severity_percentage_2021 = np.round(severity_percentage_2021, 2)
(severity_percentage_2021)
# Out:
# Accident_Severity
# Slight     85.37
# Serious    13.39
# Fatal       1.24
# Name: proportion, dtype: float64

# %% [markdown]
# <H2>Insight 6. There is 85.37% percent of slight accidents in 2021 followed by 13.39% of serious accidents and 1.24% of fatal accidents</H2>

# %% [markdown]
# <h1>5. DOES FATALITY OF ACCIDENT LESSEN EACH YEAR?</h1>

# %% [markdown]
# <H2>Insight No. 7 BASED ON THE DATA FROM YEARS 2019-2021 THE PERCENTAGE OF FATALITY DROP FROM 1.55% TO 1.24% SHOWING THAT FATALITY LESSEN EVERY YEAR</H2>

# %% [markdown]
# <H1>6. WHAT IS THE PERCENTAGE OF SEVERITY IN 2022?</H1>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'])
accident['Year'] = accident['Accident Date'].dt.year
accident_2022 = accident[accident['Year'] == 2022]
severity_percentage_2022 = accident_2022['Accident_Severity'].value_counts(normalize=True) * 100
severity_percentage_2022 = np.round(severity_percentage_2022, 2)
(severity_percentage_2022)
# Out:
# Accident_Severity
# Slight     86.11
# Serious    12.79
# Fatal       1.10
# Name: proportion, dtype: float64

# %% [markdown]
# <H2>Insight 8. There is 86.11% percent of slight accidents in 2022 followed by 12.79% of serious accidents and 1.10% of fatal accidents</H2>

# %% [markdown]
# <H1>BIVARIATE</H1>

# %% [markdown]
# <h1>7. WHAT VEHICLE HAS THE MOST FATAL SEVERITY ACCIDENT?</h1>

# %%
fatal_accidents_percentage = accident[accident['Accident_Severity'] == 'Fatal'] \
    .groupby('Vehicle_Type').size() / accident.groupby('Vehicle_Type').size() * 100
fatal_accidents_percentage = np.round(fatal_accidents_percentage, 2)
(fatal_accidents_percentage)
# Out:
# Vehicle_Type
# Agricultural vehicle                     1.08
# Bus or coach (17 or more pass seats)     1.26
# Car                                      1.32
# Data missing or out of range             0.00
# Goods 7.5 tonnes mgw and over            1.25
# Goods over 3.5t. and under 7.5t          1.10
# Minibus (8 - 16 passenger seats)         1.47
# Motorcycle 125cc and under               1.24
# Motorcycle 50cc and under                1.25
# Motorcycle over 125cc and up to 500cc    1.37
# Motorcycle over 500cc                    1.32
# Other vehicle                            1.24
# Pedal cycle                              3.05
# Ridden horse                             0.00
# Taxi/Private hire car                    1.17
# Van / Goods 3.5 tonnes mgw or under      1.37
# dtype: float64

# %% [markdown]
# <H2>Insight 9. PEDAL CYCLE HAS MOST PERCENTAGE OF FATAL ACCIDENTS WITH 3.05%</H2>

# %% [markdown]
# <h1>8. WHAT VEHICLE HAS THE MOST SERIOUS SEVERITY ACCIDENT?</h1>

# %%
fatal_accidents_percentage = accident[accident['Accident_Severity'] == 'Serious'] \
    .groupby('Vehicle_Type').size() / accident.groupby('Vehicle_Type').size() * 100
fatal_accidents_percentage = np.round(fatal_accidents_percentage, 2)
(fatal_accidents_percentage)
# Out:
# Vehicle_Type
# Agricultural vehicle                     14.48
# Bus or coach (17 or more pass seats)     13.03
# Car                                      13.35
# Data missing or out of range              0.00
# Goods 7.5 tonnes mgw and over            13.41
# Goods over 3.5t. and under 7.5t          14.06
# Minibus (8 - 16 passenger seats)         13.97
# Motorcycle 125cc and under               13.30
# Motorcycle 50cc and under                13.34
# Motorcycle over 125cc and up to 500cc    13.24
# Motorcycle over 500cc                    13.47
# Other vehicle                            13.61
# Pedal cycle                              19.80
# Ridden horse                              0.00
# Taxi/Private hire car                    13.32
# Van / Goods 3.5 tonnes mgw or under      13.33
# dtype: float64

# %% [markdown]
# <H2>Insight 10. PEDAL CYCLE HAS MOST PERCENTAGE OF SERIOUS ACCIDENTS WITH 19.80%</H2>

# %% [markdown]
# <h1>9. WHAT VEHICLE HAS THE MOST SLIGHT SEVERITY ACCIDENT?</h1>

# %%
fatal_accidents_percentage = accident[accident['Accident_Severity'] == 'Slight'] \
    .groupby('Vehicle_Type').size() / accident.groupby('Vehicle_Type').size() * 100
fatal_accidents_percentage = np.round(fatal_accidents_percentage, 2)
(fatal_accidents_percentage)
# Out:
# Vehicle_Type
# Agricultural vehicle                      84.44
# Bus or coach (17 or more pass seats)      85.71
# Car                                       85.33
# Data missing or out of range             100.00
# Goods 7.5 tonnes mgw and over             85.34
# Goods over 3.5t. and under 7.5t           84.84
# Minibus (8 - 16 passenger seats)          84.56
# Motorcycle 125cc and under                85.46
# Motorcycle 50cc and under                 85.41
# Motorcycle over 125cc and up to 500cc     85.38
# Motorcycle over 500cc                     85.20
# Other vehicle                             85.15
# Pedal cycle                               77.16
# Ridden horse                             100.00
# Taxi/Private hire car                     85.51
# Van / Goods 3.5 tonnes mgw or under       85.30
# dtype: float64

# %% [markdown]
# <H2>Insight 11. Bus or coach (17 or more pass seats) HAS MOST PERCENTAGE OF SLIGHT ACCIDENTS WITH 85.71% FOLLOWED BY TAXI/PRIVATE HIRE CAR WITH 85.51%"</H2>

# %% [markdown]
# <H1>10.DOES ROAD TYPE AFFECTS THE SEVERITY OF ACCIDENTS</H1>

# %%
severity_by_road_type = accident.groupby(['Road_Type', 'Accident_Severity']).size()
severity_by_road_type_percentage = severity_by_road_type / severity_by_road_type.groupby('Road_Type').transform('sum') * 100
severity_by_road_type_percentage = np.round(severity_by_road_type_percentage, 2)
(severity_by_road_type_percentage)
# Out:
# Road_Type           Accident_Severity
# Dual carriageway    Fatal                 1.83
#                     Serious              11.81
#                     Slight               86.36
# One way street      Fatal                 0.70
#                     Serious              12.21
#                     Slight               87.09
# Roundabout          Fatal                 0.32
#                     Serious               8.33
#                     Slight               91.35
# Single carriageway  Fatal                 1.32
#                     Serious              14.20
#                     Slight               84.48
# Slip road           Fatal                 0.70
#                     Serious               8.68
#                     Slight               90.63
# dtype: float64

# %% [markdown]
# <h2>Insight 12. Single carriage and Dual Carriage way has the most Fatal Accident Severity </h2>

# %% [markdown]
# <h1>11.WHAT ROAD TYPE HAS THE SLIGHTEST ACCIDENT SEVERITY?</h1>

# %% [markdown]
# <H2>Insight 13. ROUNDABOUT HAS MOST PERCENTAGE OF SLIGHTEST ACCIDENT SEVERITY WITH 91.35%</H2>

# %% [markdown]
# <h1>12.WHAT ROAD TYPE HAS THE MOST SERIOUS ACCIDENT SEVERITY?</h1>

# %% [markdown]
# <H2>Insight 14. SINGLE CARRIEGEWAY HAS MOST PERCENTAGE OF SERIOUS ACCIDENT SEVERITY WITH 14.20%</H2>

# %% [markdown]
# <h1>13. WHAT ROAD TYPE HAS THE MOST FATAL ACCIDENT SEVERITY?</h1>

# %% [markdown]
# <H2>Insight 15. DUAL CARRIAGEWAY HAS MOST PERCENTAGE OF FATAL ACCIDENT SEVERITY WITH 1.83%</H2

# %% [markdown]
# <H1>14. DOES LIGHT CONDITION AFFECTS ACCIDENT SEVERITY</H1>

# %%
light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().reset_index(name='Count')
(light_severity_counts)
# Out:
#                Light_Conditions Accident_Severity   Count
# 0   Darkness - lighting unknown             Fatal      68
# 1   Darkness - lighting unknown           Serious     794
# 2   Darkness - lighting unknown            Slight    5622
# 3         Darkness - lights lit             Fatal    1860
# 4         Darkness - lights lit           Serious   19130
# 5         Darkness - lights lit            Slight  108345
# 6       Darkness - lights unlit             Fatal      45
# 7       Darkness - lights unlit           Serious     360
# 8       Darkness - lights unlit            Slight    2138
# 9        Darkness - no lighting             Fatal    1612
# 10       Darkness - no lighting           Serious    7174
# 11       Darkness - no lighting            Slight   28651
# 12                     Daylight             Fatal    5076
# 13                     Daylight           Serious   60759
# 14                     Daylight            Slight  419045

# %% [markdown]
# <H2>Insight 16. From the data that we have gathered we've seen that the light conditions has impact on the severity of accidents</H2

# %%
light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().reset_index(name='Count')
total_by_light = light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum')
light_severity_counts['Percentage'] = (light_severity_counts['Count'] / total_by_light) * 100
light_severity_counts = np.round(light_severity_counts, 2)
(light_severity_counts)
# Out:
#                Light_Conditions Accident_Severity   Count  Percentage
# 0   Darkness - lighting unknown             Fatal      68        1.05
# 1   Darkness - lighting unknown           Serious     794       12.25
# 2   Darkness - lighting unknown            Slight    5622       86.71
# 3         Darkness - lights lit             Fatal    1860        1.44
# 4         Darkness - lights lit           Serious   19130       14.79
# 5         Darkness - lights lit            Slight  108345       83.77
# 6       Darkness - lights unlit             Fatal      45        1.77
# 7       Darkness - lights unlit           Serious     360       14.16
# 8       Darkness - lights unlit            Slight    2138       84.07
# 9        Darkness - no lighting             Fatal    1612        4.31
# 10       Darkness - no lighting           Serious    7174       19.16
# 11       Darkness - no lighting            Slight   28651       76.53
# 12                     Daylight             Fatal    5076        1.05
# 13                     Daylight           Serious   60759       12.53
# 14                     Daylight            Slight  419045       86.42

# %% [markdown]
# <H2>Insight 17. Contrary to the saying that in Darkness there are more severe accidents we saw from the data that in Daylight there are more sever accidents with the total of 5076</H2

# %% [markdown]
# <H2>Insight 18. If we based on the percentage of the one with highest fatality we will see that Darkness - no lighting has the highest percentage of 4.31% </H2

# %% [markdown]
# <H2>Insight 19. If we based on the percentage of the one with the most serious severity we will see that Darkness - no lighting has the highest percentage of 19.16%</H2

# %% [markdown]
# <H2>Insight 20. If we based on the percentage of the one with slightest accident severity we will see that Darkness - lighting unknown has the highest percentage of 86.71% </H2

# %%
light_severity_counts = accident[['Light_Conditions', 'Accident_Severity']].value_counts().reset_index(name='Count')
light_severity_counts['Percentage'] = light_severity_counts['Count'] / light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum') * 100
light_severity_counts = np.round(light_severity_counts, 2)
Darklightunk_severity = light_severity_counts[light_severity_counts['Light_Conditions'] == 'Darkness - lighting unknown']
(Darklightunk_severity)
# Out:
#                Light_Conditions Accident_Severity  Count  Percentage
# 6   Darkness - lighting unknown            Slight   5622       86.71
# 11  Darkness - lighting unknown           Serious    794       12.25
# 13  Darkness - lighting unknown             Fatal     68        1.05

# %%
light_severity_counts = accident[['Light_Conditions', 'Accident_Severity']].value_counts().reset_index(name='Count')
light_severity_counts['Percentage'] = light_severity_counts['Count'] / light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum') * 100
light_severity_counts = np.round(light_severity_counts, 2)
Darklightlit_severity = light_severity_counts[light_severity_counts['Light_Conditions'] == 'Darkness - lights lit']
(Darklightlit_severity)
# Out:
#           Light_Conditions Accident_Severity  Count  Percentage
# 3   Darkness - no lighting            Slight  28651       76.53
# 5   Darkness - no lighting           Serious   7174       19.16
# 10  Darkness - no lighting             Fatal   1612        4.31

# %%
light_severity_counts = accident[['Light_Conditions', 'Accident_Severity']].value_counts().reset_index(name='Count')
light_severity_counts['Percentage'] = light_severity_counts['Count'] / light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum') * 100
light_severity_counts = np.round(light_severity_counts, 2)
Darklightunlit_severity = light_severity_counts[light_severity_counts['Light_Conditions'] == 'Darkness - lights unlit']
(Darklightunlit_severity)
# Out:
#            Light_Conditions Accident_Severity  Count  Percentage
# 8   Darkness - lights unlit            Slight   2138       84.07
# 12  Darkness - lights unlit           Serious    360       14.16
# 14  Darkness - lights unlit             Fatal     45        1.77

# %%
light_severity_counts = accident[['Light_Conditions', 'Accident_Severity']].value_counts().reset_index(name='Count')
light_severity_counts['Percentage'] = light_severity_counts['Count'] / light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum') * 100
light_severity_counts = np.round(light_severity_counts, 2)
Darknolight_severity = light_severity_counts[light_severity_counts['Light_Conditions'] == 'Darkness - no lighting']
(Darknolight_severity)
# Out:
#           Light_Conditions Accident_Severity  Count  Percentage
# 3   Darkness - no lighting            Slight  28651       76.53
# 5   Darkness - no lighting           Serious   7174       19.16
# 10  Darkness - no lighting             Fatal   1612        4.31

# %%
light_severity_counts = accident[['Light_Conditions', 'Accident_Severity']].value_counts().reset_index(name='Count')
light_severity_counts['Percentage'] = light_severity_counts['Count'] / light_severity_counts.groupby('Light_Conditions')['Count'].transform('sum') * 100
light_severity_counts = np.round(light_severity_counts, 2)
Daylight_severity = light_severity_counts[light_severity_counts['Light_Conditions'] == 'Daylight']
(Daylight_severity)
# Out:
#   Light_Conditions Accident_Severity   Count  Percentage
# 0         Daylight            Slight  419045       86.42
# 2         Daylight           Serious   60759       12.53
# 7         Daylight             Fatal    5076        1.05

# %% [markdown]
# <H1>MULTI-VARIATE</H1>

# %% [markdown]
# <h1>14. How does the type of road and the type of vehicle influence the severity of accidents?</h1>

# %%
severity_by_road_vehicle = accident.groupby(['Road_Type', 'Vehicle_Type', 'Accident_Severity']).size().reset_index(name='Accident_Count')
(severity_by_road_vehicle)
# Out:
#               Road_Type                           Vehicle_Type  \
# 0      Dual carriageway                   Agricultural vehicle
# 1      Dual carriageway                   Agricultural vehicle
# 2      Dual carriageway                   Agricultural vehicle
# 3      Dual carriageway   Bus or coach (17 or more pass seats)
# 4      Dual carriageway   Bus or coach (17 or more pass seats)
# 5      Dual carriageway   Bus or coach (17 or more pass seats)
# 6      Dual carriageway                                    Car
# 7      Dual carriageway                                    Car
# 8      Dual carriageway                                    Car
# 9      Dual carriageway           Data missing or out of range
# 10     Dual carriageway           Data missing or out of range
# 11     Dual carriageway           Data missing or out of range
# 12     Dual carriageway          Goods 7.5 tonnes mgw and over
# 13     Dual carriageway          Goods 7.5 tonnes mgw and over
# 14     Dual carriageway          Goods 7.5 tonnes mgw and over
# 15     Dual carriageway        Goods over 3.5t. and under 7.5t
# 16     Dual carriageway        Goods over 3.5t. and under 7.5t
# 17     Dual carriageway        Goods over 3.5t. and under 7.5t
# 18     Dual carriageway       Minibus (8 - 16 passenger seats)
# 19     Dual carriageway       Minibus (8 - 16 passenger seats)
# 20     Dual carriageway       Minibus (8 - 16 passenger seats)
# 21     Dual carriageway             Motorcycle 125cc and under
# 22     Dual carriageway             Motorcycle 125cc and under
# 94       One way street    Van / Goods 3.5 tonnes mgw or under
# 95       One way street    Van / Goods 3.5 tonnes mgw or under
# 96           Roundabout                   Agricultural vehicle
# 97           Roundabout                   Agricultural vehicle
# 98           Roundabout                   Agricultural vehicle
# 99           Roundabout   Bus or coach (17 or more pass seats)
# 100          Roundabout   Bus or coach (17 or more pass seats)
# 101          Roundabout   Bus or coach (17 or more pass seats)
# 102          Roundabout                                    Car
# 103          Roundabout                                    Car
# 104          Roundabout                                    Car
# 105          Roundabout           Data missing or out of range
# 106          Roundabout           Data missing or out of range
# 107          Roundabout           Data missing or out of range
# 108          Roundabout          Goods 7.5 tonnes mgw and over
# 109          Roundabout          Goods 7.5 tonnes mgw and over
# 110          Roundabout          Goods 7.5 tonnes mgw and over
# 111          Roundabout        Goods over 3.5t. and under 7.5t
# 112          Roundabout        Goods over 3.5t. and under 7.5t
# 113          Roundabout        Goods over 3.5t. and under 7.5t
# 114          Roundabout       Minibus (8 - 16 passenger seats)
# 115          Roundabout       Minibus (8 - 16 passenger seats)
# 116          Roundabout       Minibus (8 - 16 passenger seats)
# 117          Roundabout             Motorcycle 125cc and under
# 118          Roundabout             Motorcycle 125cc and under
# 119          Roundabout             Motorcycle 125cc and under
# 120          Roundabout              Motorcycle 50cc and under
# 121          Roundabout              Motorcycle 50cc and under
# 122          Roundabout              Motorcycle 50cc and under
# 123          Roundabout  Motorcycle over 125cc and up to 500cc
# 124          Roundabout  Motorcycle over 125cc and up to 500cc
# 125          Roundabout  Motorcycle over 125cc and up to 500cc
# 126          Roundabout                  Motorcycle over 500cc
# 127          Roundabout                  Motorcycle over 500cc
# 128          Roundabout                  Motorcycle over 500cc
# 129          Roundabout                          Other vehicle
# 130          Roundabout                          Other vehicle
# 131          Roundabout                          Other vehicle
# 132          Roundabout                            Pedal cycle
# 133          Roundabout                            Pedal cycle
# 134          Roundabout                            Pedal cycle
# 135          Roundabout                           Ridden horse
# 136          Roundabout                           Ridden horse
# 137          Roundabout                           Ridden horse
# 138          Roundabout                  Taxi/Private hire car
# 139          Roundabout                  Taxi/Private hire car
# 140          Roundabout                  Taxi/Private hire car
# 141          Roundabout    Van / Goods 3.5 tonnes mgw or under
# 142          Roundabout    Van / Goods 3.5 tonnes mgw or under
# 143          Roundabout    Van / Goods 3.5 tonnes mgw or under
# 144  Single carriageway                   Agricultural vehicle
# 145  Single carriageway                   Agricultural vehicle
# 146  Single carriageway                   Agricultural vehicle
# 147  Single carriageway   Bus or coach (17 or more pass seats)
# 148  Single carriageway   Bus or coach (17 or more pass seats)
# 149  Single carriageway   Bus or coach (17 or more pass seats)
# 150  Single carriageway                                    Car
# 151  Single carriageway                                    Car
# 152  Single carriageway                                    Car
# 153  Single carriageway           Data missing or out of range
# 154  Single carriageway           Data missing or out of range
# 155  Single carriageway           Data missing or out of range
# 156  Single carriageway          Goods 7.5 tonnes mgw and over
# 157  Single carriageway          Goods 7.5 tonnes mgw and over
# 158  Single carriageway          Goods 7.5 tonnes mgw and over
# 159  Single carriageway        Goods over 3.5t. and under 7.5t
# 160  Single carriageway        Goods over 3.5t. and under 7.5t
# 161  Single carriageway        Goods over 3.5t. and under 7.5t
# 129             Fatal               1
# 130           Serious              36
# 131            Slight             349
# 132             Fatal               0
# 133           Serious               2
# 134            Slight              14
# 135             Fatal               0
# 136           Serious               0
# 137            Slight               0
# 138             Fatal               2
# 139           Serious              64
# 140            Slight             807
# 141             Fatal               8
# 142           Serious             205
# 143            Slight            2081
# 144             Fatal              14
# 145           Serious             228
# 146            Slight            1207
# 147             Fatal             251
# 148           Serious            2661
# 149            Slight           16388
# 150             Fatal            5002
# 151           Serious           53172
# 152            Slight          316290
# 153             Fatal               0
# 154           Serious               0
# 155            Slight               5
# 156             Fatal             158
# 157           Serious            1882
# 158            Slight           10997
# 159             Fatal              49
# 160           Serious             698
# 161            Slight            3794
# 162             Fatal              24
# 163           Serious             222
# 164            Slight            1261
# 165             Fatal             150
# 166           Serious            1619
# 167            Slight            9827
# 168             Fatal              68
# 169           Serious             820
# 170            Slight            4896
# 171             Fatal              78
# 172           Serious             824
# 173            Slight            4799
# 174             Fatal             247
# 175           Serious            2746
# 176            Slight           16214
# 177             Fatal              53
# 178           Serious             612
# 179            Slight            3557
# 180             Fatal               5
# 181           Serious              30
# 182            Slight             106
# 183             Fatal               0
# 184           Serious               0
# 185            Slight               4
# 186             Fatal             115
# 187           Serious            1413
# 188            Slight            8502
# 189             Fatal             346
# 190           Serious            3613
# 191            Slight           21716
# 192             Fatal               0
# 193           Serious               3
# 194            Slight              24
# 195             Fatal               3
# 196           Serious              29
# 197            Slight             253
# 198             Fatal              33
# 199           Serious             458
# 200            Slight            4807
# 201             Fatal               0
# 202           Serious               0
# 203            Slight               0
# 204             Fatal               2
# 205           Serious              15
# 206            Slight             171
# 207             Fatal               1
# 208           Serious               0
# 209            Slight              57
# 210             Fatal               0
# 211           Serious               1
# 212            Slight              15
# 213             Fatal               1
# 214           Serious              11
# 215            Slight             135
# 216             Fatal               0
# 217           Serious               8
# 218            Slight              81
# 219             Fatal               0
# 220           Serious               9
# 221            Slight              89
# 222             Fatal               2
# 223           Serious              20
# 224            Slight             262
# 225             Fatal               1
# 226           Serious               9
# 227            Slight              54
# 228             Fatal               0
# 229           Serious               0
# 230            Slight               2
# 231             Fatal               0
# 232           Serious               0
# 233            Slight               0
# 234             Fatal               0
# 235           Serious              21
# 236            Slight             103
# 237             Fatal               6
# 238           Serious              27
# 239            Slight             328

# %%
fatal_accidents = severity_by_road_vehicle[severity_by_road_vehicle['Accident_Severity'] == 'Fatal']
total_accidents = severity_by_road_vehicle.groupby(['Road_Type', 'Vehicle_Type'])['Accident_Count'].sum().reset_index(name='Total_Accidents')
fatal_percentage = pd.merge(fatal_accidents, total_accidents, on=['Road_Type', 'Vehicle_Type'])
fatal_percentage['Fatal_Percentage'] = (fatal_percentage['Accident_Count'] / fatal_percentage['Total_Accidents']) * 100
fatal_percentage['Fatal_Percentage'] = fatal_percentage['Fatal_Percentage'].round(2)
(fatal_percentage)
# Out:
#              Road_Type                           Vehicle_Type  \
# 0     Dual carriageway                   Agricultural vehicle
# 1     Dual carriageway   Bus or coach (17 or more pass seats)
# 2     Dual carriageway                                    Car
# 3     Dual carriageway           Data missing or out of range
# 4     Dual carriageway          Goods 7.5 tonnes mgw and over
# 5     Dual carriageway        Goods over 3.5t. and under 7.5t
# 6     Dual carriageway       Minibus (8 - 16 passenger seats)
# 7     Dual carriageway             Motorcycle 125cc and under
# 8     Dual carriageway              Motorcycle 50cc and under
# 9     Dual carriageway  Motorcycle over 125cc and up to 500cc
# 10    Dual carriageway                  Motorcycle over 500cc
# 11    Dual carriageway                          Other vehicle
# 12    Dual carriageway                            Pedal cycle
# 13    Dual carriageway                           Ridden horse
# 14    Dual carriageway                  Taxi/Private hire car
# 15    Dual carriageway    Van / Goods 3.5 tonnes mgw or under
# 16      One way street                   Agricultural vehicle
# 17      One way street   Bus or coach (17 or more pass seats)
# 18      One way street                                    Car
# 19      One way street           Data missing or out of range
# 20      One way street          Goods 7.5 tonnes mgw and over
# 21      One way street        Goods over 3.5t. and under 7.5t
# 22      One way street       Minibus (8 - 16 passenger seats)
# 23      One way street             Motorcycle 125cc and under
# 24      One way street              Motorcycle 50cc and under
# 25      One way street  Motorcycle over 125cc and up to 500cc
# 26      One way street                  Motorcycle over 500cc
# 27      One way street                          Other vehicle
# 28      One way street                            Pedal cycle
# 29      One way street                           Ridden horse
# 30      One way street                  Taxi/Private hire car
# 31      One way street    Van / Goods 3.5 tonnes mgw or under
# 32          Roundabout                   Agricultural vehicle
# 33          Roundabout   Bus or coach (17 or more pass seats)
# 34          Roundabout                                    Car
# 35          Roundabout           Data missing or out of range
# 36          Roundabout          Goods 7.5 tonnes mgw and over
# 37          Roundabout        Goods over 3.5t. and under 7.5t
# 38          Roundabout       Minibus (8 - 16 passenger seats)
# 39          Roundabout             Motorcycle 125cc and under
# 40          Roundabout              Motorcycle 50cc and under
# 41          Roundabout  Motorcycle over 125cc and up to 500cc
# 42          Roundabout                  Motorcycle over 500cc
# 43          Roundabout                          Other vehicle
# 44          Roundabout                            Pedal cycle
# 45          Roundabout                           Ridden horse
# 46          Roundabout                  Taxi/Private hire car
# 47          Roundabout    Van / Goods 3.5 tonnes mgw or under
# 48  Single carriageway                   Agricultural vehicle
# 49  Single carriageway   Bus or coach (17 or more pass seats)
# 50  Single carriageway                                    Car
# 51  Single carriageway           Data missing or out of range
# 52  Single carriageway          Goods 7.5 tonnes mgw and over
# 53  Single carriageway        Goods over 3.5t. and under 7.5t
# 54  Single carriageway       Minibus (8 - 16 passenger seats)
# 55  Single carriageway             Motorcycle 125cc and under
# 56  Single carriageway              Motorcycle 50cc and under
# 57  Single carriageway  Motorcycle over 125cc and up to 500cc
# 58  Single carriageway                  Motorcycle over 500cc
# 59  Single carriageway                          Other vehicle
# 60  Single carriageway                            Pedal cycle
# 61  Single carriageway                           Ridden horse
# 62  Single carriageway                  Taxi/Private hire car
# 63  Single carriageway    Van / Goods 3.5 tonnes mgw or under
# 64           Slip road                   Agricultural vehicle
# 65           Slip road   Bus or coach (17 or more pass seats)
# 66           Slip road                                    Car
# 67           Slip road           Data missing or out of range
# 68           Slip road          Goods 7.5 tonnes mgw and over
# 69           Slip road        Goods over 3.5t. and under 7.5t
# 70           Slip road       Minibus (8 - 16 passenger seats)
# 71           Slip road             Motorcycle 125cc and under
# 72           Slip road              Motorcycle 50cc and under
# 73           Slip road  Motorcycle over 125cc and up to 500cc
# 74           Slip road                  Motorcycle over 500cc
# 75           Slip road                          Other vehicle
# 76           Slip road                            Pedal cycle
# 77           Slip road                           Ridden horse
# 78           Slip road                  Taxi/Private hire car
# 79           Slip road    Van / Goods 3.5 tonnes mgw or under
#
#    Accident_Severity  Accident_Count  Total_Accidents  Fatal_Percentage
# 0              Fatal               6              293              2.05
# 1              Fatal              63             4043              1.56
# 2              Fatal            1364            74820              1.82
# 3              Fatal               0                1              0.00
# 4              Fatal              49             2631              1.86
# 5              Fatal              13              959              1.36
# 6              Fatal               5              275              1.82
# 7              Fatal              33             2228              1.48
# 8              Fatal              23             1085              2.12
# 9              Fatal              22             1210              1.82
# 10             Fatal              82             3930              2.09
# 11             Fatal              14              835              1.68
# 12             Fatal               1               34              2.94
# 13             Fatal               0                0               NaN
# 14             Fatal              37             1973              1.88
# 15             Fatal             103             5107              2.02
# 16             Fatal               1               49              2.04
# 17             Fatal               2              546              0.37
# 18             Fatal              69            10223              0.67
# 19             Fatal               0                0               NaN
# 20             Fatal               3              341              0.88
# 21             Fatal               4              116              3.45
# 22             Fatal               0               40              0.00
# 23             Fatal               2              307              0.65
# 24             Fatal               4              133              3.01
# 25             Fatal               0              154              0.00
# 26             Fatal               4              499              0.80
# 27             Fatal               1              130              0.77
# 28             Fatal               0                4              0.00
# 29             Fatal               0                0               NaN
# 30             Fatal               1              294              0.34
# 31             Fatal               4              723              0.55
# 32             Fatal               0              129              0.00
# 33             Fatal               6             1704              0.35
# 34             Fatal             109            33187              0.33
# 35             Fatal               0                0               NaN
# 36             Fatal               4             1110              0.36
# 37             Fatal               0              422              0.00
# 38             Fatal               0              138              0.00
# 39             Fatal               3              991              0.30
# 40             Fatal               0              512              0.00
# 41             Fatal               5              493              1.01
# 42             Fatal               4             1737              0.23
# 43             Fatal               1              386              0.26
# 44             Fatal               0               16              0.00
# 45             Fatal               0                0               NaN
# 46             Fatal               2              873              0.23
# 47             Fatal               8             2294              0.35
# 48             Fatal              14             1449              0.97
# 49             Fatal             251            19300              1.30
# 50             Fatal            5002           374464              1.34
# 51             Fatal               0                5              0.00
# 52             Fatal             158            13037              1.21
# 53             Fatal              49             4541              1.08
# 54             Fatal              24             1507              1.59
# 55             Fatal             150            11596              1.29
# 56             Fatal              68             5784              1.18
# 57             Fatal              78             5701              1.37
# 58             Fatal             247            19207              1.29
# 59             Fatal              53             4222              1.26
# 60             Fatal               5              141              3.55
# 61             Fatal               0                4              0.00
# 62             Fatal             115            10030              1.15
# 63             Fatal             346            25675              1.35
# 64             Fatal               0               27              0.00
# 65             Fatal               3              285              1.05
# 66             Fatal              33             5298              0.62
# 67             Fatal               0                0               NaN
# 68             Fatal               2              188              1.06
# 69             Fatal               1               58              1.72
# 70             Fatal               0               16              0.00
# 71             Fatal               1              147              0.68
# 72             Fatal               0               89              0.00
# 73             Fatal               0               98              0.00
# 74             Fatal               2              284              0.70
# 75             Fatal               1               64              1.56
# 76             Fatal               0                2              0.00
# 77             Fatal               0                0               NaN
# 78             Fatal               0              124              0.00
# 79             Fatal               6              361              1.66
